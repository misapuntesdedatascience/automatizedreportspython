# %%
import random
import pandas as pd

# %%
barrios = ['Centro','Carabanchel','Retiro','Salamanca','Tetúan','Fuencarral','Usera','Moratalaz','Hortaleza']

# %%
dataEne = {'Barrio':  barrios,
           'Mes': 1,
           'Pases Diarios': random.sample(range(700, 1800), 9),
           'Altas': random.sample(range(50, 200), 9),
           'Bajas': random.sample(range(20, 90), 9),
           'Aforo Spining %': random.sample(range(50, 80), 9),
           'Aforo Zumba %': random.sample(range(50, 80), 9),
           'Aforo Pilates %': random.sample(range(50, 80), 9)}

# %%
reportEne = pd.DataFrame(dataEne)

# %%
reportEne
# Out:
#         Barrio  Mes  Pases Diarios  Altas  Bajas  Aforo Spining %  \
# 0       Centro    1           1753    163     58               62
# 1  Carabanchel    1           1293    160     61               72
# 2       Retiro    1           1572     77     31               63
# 3    Salamanca    1            705     73     22               54
# 4       Tetúan    1            943     71     53               68
# 5   Fuencarral    1           1249     59     52               74
# 6        Usera    1           1095    179     87               50
# 7    Moratalaz    1           1132    140     62               64
# 8    Hortaleza    1            816    148     48               60
#
#    Aforo Zumba %  Aforo Pilates %
# 0             74               60
# 1             57               73
# 2             52               61
# 3             69               68
# 4             53               74
# 5             63               52
# 6             50               55
# ...

# %%
dataFeb = {'Barrio':  barrios,
           'Mes': 2,
             'Pases Diarios': random.sample(range(700, 1800), 9),
             'Altas': random.sample(range(50, 200), 9),
             'Bajas': random.sample(range(20, 90), 9),
             'Aforo Spining %': random.sample(range(50, 80), 9),
             'Aforo Zumba %': random.sample(range(50, 80), 9),
             'Aforo Pilates %': random.sample(range(50, 80), 9)}

# %%
reportFeb = pd.DataFrame(dataFeb)

# %%
reportFeb
# Out:
#         Barrio  Mes  Pases Diarios  Altas  Bajas  Aforo Spining %  \
# 0       Centro    2           1177    132     33               60
# 1  Carabanchel    2            819    126     30               74
# 2       Retiro    2            893     86     48               69
# 3    Salamanca    2           1285    106     47               50
# 4       Tetúan    2           1697    142     50               53
# 5   Fuencarral    2           1494    177     43               61
# 6        Usera    2            815     83     57               62
# 7    Moratalaz    2           1559    196     25               67
# 8    Hortaleza    2            751     78     28               70
#
#    Aforo Zumba %  Aforo Pilates %
# 0             57               55
# 1             62               71
# 2             73               56
# 3             50               52
# 4             69               64
# 5             76               73
# 6             52               76
# ...

# %%
reportEne.to_excel(r'reportEne.xlsx', index = False)

# %%
reportFeb.to_excel(r'reportFeb.xlsx', index = False)
